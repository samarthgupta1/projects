# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import os 
path=os.getcwd()+"\desktop\Big_mart.csv"
df=pd.read_csv(path)
df.head()
s=df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.1+ KB

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.isnull()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# 5               False        False             False            False
# 6               False        False             False            False
# 7               False         True             False            False
# 8               False        False             False            False
# 9               False        False             False            False
# 10              False        False             False            False
# 11              False        False             False            False
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df["Item_Fat_Content"]
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
# 5       Regular
# 6       Regular
# 7       Low Fat
# 8       Regular
# 9       Regular
# 10      Low Fat
# 11      Regular
# 12      Regular
# 13      Regular
# 14      Low Fat
# 15      Regular
# 16      Low Fat
# 17      Regular
# 18      Low Fat
# 19      Low Fat
# 20      Regular
# 21      Regular
# 22      Low Fat
# 23      Low Fat
# 24      Regular
# 25      Low Fat
# 26      Regular
# 27      low fat
# 28      Regular
# 29      Regular
#          ...
# 8493    Regular
# 8494    Low Fat
# 8495    Low Fat
# 8496    Regular
# 8497    Low Fat
# 8498    Low Fat
# 8499    Low Fat
# 8500    Low Fat
# 8501    Regular
# 8502    Low Fat
# 8503    Low Fat
# 8504    Low Fat
# 8505    Regular
# 8506    Low Fat
# 8507    Regular
# 8508    Regular
# 8509    Low Fat
# 8510    Regular
# 8511    Low Fat
# 8512    Low Fat
# 8513    Regular
# 8514    Regular
# 8515    Low Fat
# 8516    Low Fat
# ...

# %%
s.replace("low fat","Low Fat",inplace=True)
s.replace("regular","Regular",inplace=True)
s.replace("LF","Low Fat",inplace=True)
s.replace("reg","Regular",inplace=True)

# %%
s["Item_Fat_Content"]
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
# 5       Regular
# 6       Regular
# 7       Low Fat
# 8       Regular
# 9       Regular
# 10      Low Fat
# 11      Regular
# 12      Regular
# 13      Regular
# 14      Low Fat
# 15      Regular
# 16      Low Fat
# 17      Regular
# 18      Low Fat
# 19      Low Fat
# 20      Regular
# 21      Regular
# 22      Low Fat
# 23      Low Fat
# 24      Regular
# 25      Low Fat
# 26      Regular
# 27      Low Fat
# 28      Regular
# 29      Regular
#          ...
# 8493    Regular
# 8494    Low Fat
# 8495    Low Fat
# 8496    Regular
# 8497    Low Fat
# 8498    Low Fat
# 8499    Low Fat
# 8500    Low Fat
# 8501    Regular
# 8502    Low Fat
# 8503    Low Fat
# 8504    Low Fat
# 8505    Regular
# 8506    Low Fat
# 8507    Regular
# 8508    Regular
# 8509    Low Fat
# 8510    Regular
# 8511    Low Fat
# 8512    Low Fat
# 8513    Regular
# 8514    Regular
# 8515    Low Fat
# 8516    Low Fat
# ...

# %%
q=df.loc[:,"Outlet_Size"].mode()
print (q)
w=df.loc[:,"Item_Weight"].median()
print (w)
#values={"Outlet_Size":q}
#df['Outlet_Size'].fillna("Medium")
#e=df["Item_Weight"].fillna(w)
#s=df.fillna(df.mode())
#rint(t)
#.Outlet_Size
#df["Outlet_Size"].replace("NaN","Medium",inplace=True)
#df["Outlet_Size"]
#a.Outlet_Size
#sns.distplot(s.Item_Weight,kde=True)
#df["Outlet_Size"]
#e["Item_Weight"]
#e["Outlet_Size"]
#print(df["Outlet_Size"].mode())
df["Item_Weight"]=df["Item_Weight"].fillna(df["Item_Weight"].median())
#df["Outlet_Size"].fillna("Medium")
df["Item_Weight"]
#df["Outlet_Size"]
# Out:
# 0    Medium
# dtype: object
# 12.6
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
# 5       10.395
# 6       13.650
# 7       12.600
# 8       16.200
# 9       19.200
# 10      11.800
# 11      18.500
# 12      15.100
# 13      17.600
# 14      16.350
# 15       9.000
# 16      11.800
# 17       9.000
# 18      12.600
# 19      13.350
# 20      18.850
# 21      12.600
# 22      14.600
# 23      12.600
# 24      13.850
# 25      13.000
# 26       7.645
# 27      11.650
# 28       5.925
# 29      12.600
#          ...
# 8493     7.420
# 8494    15.200
# 8495     9.695
# 8496     7.420
# 8497    13.650
# 8498    15.350
# 8499    11.600
# 8500    20.350
# 8501     5.340
# 8502     8.420
# 8503    20.500
# 8504    12.600
# 8505    10.500
# 8506    17.250
# 8507     5.880
# 8508    11.350
# 8509     8.100
# 8510    13.800
# 8511    17.500
# 8512    20.700
# 8513    12.000
# 8514    15.000
# 8515    20.700
# 8516    18.600
# 8517    20.750
# ...

# %%
df["Outlet_Size"]=df["Outlet_Size"].fillna("Medium")
s["Outlet_Size"]
#df["Item_Weight"]
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3       Medium
# 4         High
# 5       Medium
# 6         High
# 7       Medium
# 8       Medium
# 9       Medium
# 10      Medium
# 11       Small
# 12      Medium
# 13       Small
# 14        High
# 15       Small
# 16      Medium
# 17      Medium
# 18      Medium
# 19       Small
# 20        High
# 21      Medium
# 22       Small
# 23       Small
# 24       Small
# 25      Medium
# 26       Small
# 27        High
# 28      Medium
# 29       Small
#          ...
# 8493    Medium
# 8494    Medium
# 8495     Small
# 8496    Medium
# 8497     Small
# 8498    Medium
# 8499     Small
# 8500    Medium
# 8501    Medium
# 8502    Medium
# 8503     Small
# 8504    Medium
# 8505    Medium
# 8506    Medium
# 8507     Small
# 8508    Medium
# 8509    Medium
# 8510     Small
# 8511    Medium
# 8512      High
# 8513     Small
# 8514    Medium
# 8515    Medium
# 8516    Medium
# 8517     Small
# 8518      High
# 8519    Medium
# ...

# %%
a=df["Outlet_Size"]
y=a.replace("NaN","Medium")
print("KKKKK",y)
# Out:
# KKKKK 0       Medium
# 1       Medium
# 2       Medium
# 3       Medium
# 4         High
# 5       Medium
# 6         High
# 7       Medium
# 8       Medium
# 9       Medium
# 10      Medium
# 11       Small
# 12      Medium
# 13       Small
# 14        High
# 15       Small
# 16      Medium
# 17      Medium
# 18      Medium
# 19       Small
# 20        High
# 21      Medium
# 22       Small
# 23       Small
# 24       Small
# 25      Medium
# 26       Small
# 27        High
# 28      Medium
# 29       Small
#          ...
# 8493    Medium
# 8494    Medium
# 8495     Small
# 8496    Medium
# 8497     Small
# 8498    Medium
# 8499     Small
# 8500    Medium
# 8501    Medium
# 8502    Medium
# 8503     Small
# 8504    Medium
# 8505    Medium
# 8506    Medium
# 8507     Small
# 8508    Medium
# 8509    Medium
# 8510     Small
# 8511    Medium
# 8512      High
# 8513     Small
# 8514    Medium
# 8515    Medium
# 8516    Medium
# 8517     Small
# 8518      High
# 8519    Medium
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
#del s["Outlet_Size"]
#del s["salary"]
s["Outlet_Size"]=y
s
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10       12.600          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  8523 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  8523 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.1+ KB

# %%
s.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count   8523.00000      8523.000000  8523.000000                8523.000000
# mean      12.81342         0.066132   140.992782                1997.831867
# std        4.22724         0.051598    62.275067                   8.371760
# min        4.55500         0.000000    31.290000                1985.000000
# 25%        9.31000         0.026989    93.826500                1987.000000
# 50%       12.60000         0.053931   143.012800                1999.000000
# 75%       16.00000         0.094585   185.643700                2004.000000
# max       21.35000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
s.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
sns.distplot(s["Item_Weight"],kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(s["Item_Visibility"],kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(s["Item_MRP"],kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(s["Item_Outlet_Sales"],kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
s.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count   8523.00000      8523.000000  8523.000000                8523.000000
# mean      12.81342         0.066132   140.992782                1997.831867
# std        4.22724         0.051598    62.275067                   8.371760
# min        4.55500         0.000000    31.290000                1985.000000
# 25%        9.31000         0.026989    93.826500                1987.000000
# 50%       12.60000         0.053931   143.012800                1999.000000
# 75%       16.00000         0.094585   185.643700                2004.000000
# max       21.35000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
s.describe(include="object")
# Out:
#        Item_Identifier Item_Fat_Content              Item_Type  \
# count             8523             8523                   8523
# unique            1559                2                     16
# top              FDG33          Low Fat  Fruits and Vegetables
# freq                10             5517                   1232
#
#        Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# count               8523        8523                 8523               8523
# unique                10           3                    3                  4
# top               OUT027      Medium               Tier 3  Supermarket Type1
# freq                 935        5203                 3350               5577

# %%
sns.boxplot(data=s["Item_Weight"])

# %%
sns.boxplot(data=s["Item_Visibility"])

# %%
sns.boxplot(data=s["Item_MRP"])

# %%
sns.boxplot(data=s["Outlet_Establishment_Year"])

# %%
sns.boxplot(data=s["Item_Outlet_Sales"])

# %%
s=s[s["Item_Outlet_Sales"]<6200]
sns.boxplot(data=s["Item_Outlet_Sales"])

# %%
s["Item_Outlet_Sales"]
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
# 5        556.6088
# 6        343.5528
# 7       4022.7636
# 8       1076.5986
# 9       4710.5350
# 10      1516.0266
# 11      2187.1530
# 12      1589.2646
# 13      2145.2076
# 14      1977.4260
# 15      1547.3192
# 16      1621.8888
# 17       718.3982
# 18      2303.6680
# 19      2748.4224
# 20      3775.0860
# 21      4064.0432
# 22      1587.2672
# 23       214.3876
# 24      4078.0250
# 25       838.9080
# 26      1065.2800
# 27       308.9312
# 28       178.4344
# 29       125.8362
#           ...
# 8492    2419.5172
# 8493    4727.1800
# 8494    1637.8680
# 8495    4314.3840
# 8496    3715.1640
# 8497    2247.0750
# 8498    1601.2490
# 8499    2976.1260
# 8500    1907.5170
# 8501    1508.0370
# 8502    3020.0688
# 8503    3392.9168
# 8504    4138.6128
# 8505    2117.2440
# 8506    3944.8650
# 8507     515.9950
# 8508    2587.9646
# 8509     424.7804
# 8511    4207.8560
# ...

# %%
s=s[s["Item_Visibility"]<=0.185]
sns.boxplot(data=s["Item_Visibility"])

# %%
s["Item_Visibility"]
# Out:
# 0       0.016047
# 1       0.019278
# 2       0.016760
# 3       0.000000
# 4       0.000000
# 5       0.000000
# 6       0.012741
# 7       0.127470
# 8       0.016687
# 9       0.094450
# 10      0.000000
# 11      0.045464
# 12      0.100014
# 13      0.047257
# 14      0.068024
# 15      0.069089
# 16      0.008596
# 17      0.069196
# 18      0.034238
# 19      0.102492
# 20      0.138190
# 21      0.035400
# 22      0.025698
# 23      0.057557
# 24      0.025896
# 25      0.099887
# 26      0.066693
# 27      0.019356
# 28      0.161467
# 29      0.072222
#           ...
# 8491    0.037033
# 8492    0.174350
# 8493    0.025886
# 8494    0.000000
# 8495    0.029567
# 8496    0.021696
# 8497    0.049209
# 8498    0.035293
# 8499    0.037574
# 8500    0.000000
# 8501    0.005998
# 8502    0.070712
# 8503    0.036133
# 8504    0.124111
# 8505    0.094146
# 8506    0.084676
# 8507    0.030242
# 8508    0.043246
# 8511    0.026980
# 8512    0.042801
# 8513    0.020407
# ...

# %%
sns.countplot(x="Item_Fat_Content",data=s)

# %%
sns.countplot(x="Outlet_Size",data=s)

# %%
plt.figure(figsize=(25,20))
sns.countplot(x="Item_Type",data=s)

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="Outlet_Identifier",data=s)

# %%
sns.countplot(x="Outlet_Location_Type",data=s)

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="Outlet_Type",data=s)

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8203 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8203 non-null object
# Item_Weight                  8203 non-null float64
# Item_Fat_Content             8203 non-null object
# Item_Visibility              8203 non-null float64
# Item_Type                    8203 non-null object
# Item_MRP                     8203 non-null float64
# Outlet_Identifier            8203 non-null object
# Outlet_Establishment_Year    8203 non-null int64
# Outlet_Size                  8203 non-null object
# Outlet_Location_Type         8203 non-null object
# Outlet_Type                  8203 non-null object
# Item_Outlet_Sales            8203 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.1+ MB

# %%
sns.barplot(y="Item_Weight",x="Item_Fat_Content",data=s)

# %%
sns.barplot(y="Item_Visibility",x="Item_Fat_Content",data=s)

# %%
sns.barplot(y="Item_MRP",x="Item_Fat_Content",data=s)

# %%
sns.barplot(y="Item_Outlet_Sales",x="Outlet_Size",data=s)

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
sns.jointplot(x="Item_Weight",y="Item_MRP",data=s)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x="Item_Weight",y="Item_Visibility",data=s)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x="Item_Visibility",y="Item_MRP",data=s)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.lmplot(x="Item_Visibility",y="Item_MRP",data=s,hue="Item_Fat_Content")

# %%
sns.lmplot(x="Item_Weight",y="Item_MRP",data=s,hue="Item_Fat_Content")

# %%
sns.lmplot(x="Item_Outlet_Sales",y="Outlet_Establishment_Year",data=s,hue="Outlet_Size")

# %%
sns.heatmap(s.corr())

# %%
s.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
from sklearn import preprocessing
f=s["Item_Visibility"]
x_p=preprocessing.scale(f)
x_p
b=s["Item_Outlet_Sales"]
x_b=preprocessing.scale(b)
x_b
# Out:
# array([ 1.13834453, -1.10906481,  0.02009474, ..., -0.59721552,
#        -0.15173389, -0.88905144])

# %%
sns.distplot(x_p,kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(x_b,kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
s.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
s.Item_Outlet_Sales
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
# 5        556.6088
# 6        343.5528
# 7       4022.7636
# 8       1076.5986
# 9       4710.5350
# 10      1516.0266
# 11      2187.1530
# 12      1589.2646
# 13      2145.2076
# 14      1977.4260
# 15      1547.3192
# 16      1621.8888
# 17       718.3982
# 18      2303.6680
# 19      2748.4224
# 20      3775.0860
# 21      4064.0432
# 22      1587.2672
# 23       214.3876
# 24      4078.0250
# 25       838.9080
# 26      1065.2800
# 27       308.9312
# 28       178.4344
# 29       125.8362
#           ...
# 8491    4809.7392
# 8492    2419.5172
# 8493    4727.1800
# 8494    1637.8680
# 8495    4314.3840
# 8496    3715.1640
# 8497    2247.0750
# 8498    1601.2490
# 8499    2976.1260
# 8500    1907.5170
# 8501    1508.0370
# 8502    3020.0688
# 8503    3392.9168
# 8504    4138.6128
# 8505    2117.2440
# 8506    3944.8650
# 8507     515.9950
# 8508    2587.9646
# 8511    4207.8560
# ...

# %%
x_b
# Out:
# array([ 1.13834453, -1.10906481,  0.02009474, ..., -0.59721552,
#        -0.15173389, -0.88905144])

# %%
#sns.distplot(l_v,kde=True)
g=s["Item_Visibility"]
l_v=g**(1/2)
l_v
p=s["Item_Outlet_Sales"]
y1=np.log(p)
y1
# Out:
# 0       8.225540
# 1       6.094524
# 2       7.648392
# 3       6.596300
# 4       6.902446
# 5       6.321863
# 6       5.839341
# 7       8.299724
# 8       6.981562
# 9       8.457557
# 10      7.323848
# 11      7.690356
# 12      7.371027
# 13      7.670992
# 14      7.589551
# 15      7.344279
# 16      7.391347
# 17      6.577024
# 18      7.742258
# 19      7.918782
# 20      8.236178
# 21      8.309934
# 22      7.369769
# 23      5.367786
# 24      8.313368
# 25      6.732101
# 26      6.970993
# 27      5.733119
# 28      5.184221
# 29      4.834981
#           ...
# 8491    8.478398
# 8492    7.791323
# 8493    8.461084
# 8494    7.401151
# 8495    8.369710
# 8496    8.220178
# 8497    7.717385
# 8498    7.378539
# 8499    7.998378
# 8500    7.553558
# 8501    7.318564
# 8502    8.013035
# 8503    8.129445
# 8504    8.328116
# 8505    7.657871
# 8506    8.280170
# 8507    6.246097
# 8508    7.858627
# 8511    8.344709
# 8512    7.815788
# 8513    6.388940
# ...

# %%
sns.distplot(l_v,kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(y1,kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(s["Outlet_Establishment_Year"],kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
s.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
from sklearn.feature_selection import VarianceThreshold
q=pd.DataFrame()
xc=s["Item_Weight"]
q["Item_Weight"]=xc
xz=s["Item_Visibility"]
q["Item_Visibility"]=l_v
xs=s["Item_MRP"]
q["Item_MRP"]=xs
xd=s["Outlet_Establishment_Year"]
q["Outlet_Establishment_Year"]=xd
q["Item_Fat_Content"]=s["Item_Fat_Content"]
q["Item_Type"]=s["Item_Type"]
q["Outlet_Size"]=s["Outlet_Size"]
q["Outlet_Location_Type"]=s["Outlet_Location_Type"]
q["Outlet_Type"]=s["Outlet_Type"]
dummies=pd.get_dummies(q)

#dummies
#del m["Item_Identifier"]
#m["Item_Identifier"]=df["Item_Identifier"]
#q["Item_Fat"]=d_a

dummies.info()

#vt=q.iloc[:1:6]
#selector=VarianceThreshold(0.5)
#selector.fit_transform(vt)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8093 entries, 0 to 8522
# Data columns (total 32 columns):
# Item_Weight                        8093 non-null float64
# Item_Visibility                    8093 non-null float64
# Item_MRP                           8093 non-null float64
# Outlet_Establishment_Year          8093 non-null int64
# Item_Fat_Content_Low Fat           8093 non-null uint8
# Item_Fat_Content_Regular           8093 non-null uint8
# Item_Type_Baking Goods             8093 non-null uint8
# Item_Type_Breads                   8093 non-null uint8
# Item_Type_Breakfast                8093 non-null uint8
# Item_Type_Canned                   8093 non-null uint8
# Item_Type_Dairy                    8093 non-null uint8
# Item_Type_Frozen Foods             8093 non-null uint8
# Item_Type_Fruits and Vegetables    8093 non-null uint8
# Item_Type_Hard Drinks              8093 non-null uint8
# Item_Type_Health and Hygiene       8093 non-null uint8
# ...

# %%
from sklearn.model_selection import train_test_split
a=np.array(y1)
u=np.array(dummies)
x_train,x_test,y_train,y_test=train_test_split(u,a,test_size=0.3,random_state=7)
print( y_train.shape,y_test.shape)

print( x_train.shape,x_test.shape)
# Out:
# (5665,) (2428,)
# (5665, 32) (2428, 32)

# %%
x=dummies
y=y1
from sklearn.linear_model import LinearRegression
reg=LinearRegression(normalize=True)
reg.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %%
y_pred=reg.predict(x)

# %%
rt=pd.DataFrame.from_dict({"actual":list(y),"predicted":list(y_pred)})
rt.head()
# Out:
#      actual  predicted
# 0  8.225540   8.317871
# 1  6.094524   6.581787
# 2  7.648392   7.542480
# 3  6.596300   5.894043
# 4  6.902446   6.762207

# %%
from sklearn import metrics

# %%
metrics.mean_squared_error(y,y_pred)
# Out:
# 0.28636751972842733

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %%
y_pre=reg.predict(x_test)

# %%
tr=pd.DataFrame.from_dict({"actual":list(y_test),"predicted":list(y_pre)})
tr.head()
# Out:
#      actual  predicted
# 0  8.268968   7.927734
# 1  5.638239   5.601562
# 2  7.654090   7.552734
# 3  7.512590   7.855469
# 4  6.038954   7.119141

# %%
from sklearn import metrics

# %%
metrics.mean_squared_error(y_test,y_pre)
# Out:
# 0.2864301527091792

# %%
x_test.shape,y_test.shape
# Out:
# ((2428, 32), (2428,))

# %%
x_test.reshape(2461,1)
y_test.reshape(2461,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-292-e113ae83981b> in <module>()
# ----> 1 x_test.reshape(2461,1)
#       2 y_test.reshape(2461,1)
#
# ValueError: cannot reshape array of size 77696 into shape (2461,1)

# %%
x_test.shape,y_test.shape
# Out:
# ((2428, 32), (2428,))

# %%
plt.scatter(x_test,y_test,color="black")
plt.plot(x_test,y_pre,color="blue",linewidth=3)
#plt.xticks(())
#plt.yticks(())
plt.show()
